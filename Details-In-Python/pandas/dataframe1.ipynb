# %% [markdown]
# 参考博客：https://blog.csdn.net/wr339988/article/details/65446138/

# %%
import numpy as np
import pandas as pd

# %%
ser = pd.Series(np.arange(3))
df = pd.DataFrame(np.arange(12).reshape(3, 4), index=[0, 1, 2], columns=['a', 'b', 'c', 'd'])

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### 基本查询

# %% [markdown]
# #### 列查询：需要columns

# %%
df["a"]  # return type is Series
# Out:
# 0    0
# 1    4
# 2    8
# Name: a, dtype: int32

# %%
df.a  # same as the above method
# Out:
# 0    0
# 1    4
# 2    8
# Name: a, dtype: int32

# %%
df[['a']]  # return type is DataFrame
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df[['a', 'b']]  # select multiple columns should be like this
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### 行查询：需要index

# %%
df[:2]  # like slice in list, [0,2)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df[1] # DF的字典属性默认是给列的，列中没有叫1的column，所以行查询必须传入切片，哪怕只要一行

# %% [markdown]
# #### 区块查询

# %%
df[:2][["a", "b"]]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### loc查询和iloc查询

# %% [markdown]
# 上述的普通方法不够强大，下面两种查询才是用的最多的方式。
# * loc: for label based indexing
# * iloc: for positional indexing
#
# 这些方法同时可以同时作用于行列。

# %% [markdown]
# #### loc方法:行根据index选择，列根据columns选择

# %%
# row 
df.loc[1]  # return type is Series
# Out:
# a    4
# b    5
# c    6
# d    7
# Name: 1, dtype: int32

# %%
# row 
df.loc[1:3]  # return type is DataFrame
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# column
df.loc[:, 'a']  # return type is Series(need to select all rows)
# Out:
# 0    0
# 1    4
# 2    8
# Name: a, dtype: int32

# %%
# column
df.loc[:, 'a':'c']  # surprize! even if column name is not a number,
# you can use slice on the column like this.
# columns names must have order
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# column
df.loc[:, ['a', 'b', 'c']]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### iloc方法：根据位置来选择，不管你的index或是column叫什么，所以方括号内都是数值

# %%
# row
df.iloc[:2]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# column
df.iloc[:,:2]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# column
df.iloc[:, [0, 1]]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# 辨析：
# * loc根据index或column的值来选择，label based
# * iloc根据具体的位置索引选择，position based
# * 至于ix方法，已经deprecated了，完全可以用下面两种方法代替

# %% [markdown]
# 注意：
# loc可以作用于不存在的index或column，效果为增加新的一行或是一列
# iloc不能超出现有数据的长度或宽度(IndexError: single positional indexer is out-of-bounds)

# %% [markdown]
# 我的使用习惯：
# 行查询都一样；列查询：
# * 少量或有序：loc
# * 大量： iloc
